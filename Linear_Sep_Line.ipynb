# %% [markdown]
# <a href="https://colab.research.google.com/github/HiteshS37/Python/blob/main/Linear_Sep_Line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prob Statement:
# Predict the students' exam score based on the number of hours studied using the linear reg line having linear seperable line.

# %%
#STEP 1 - Data Generation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#STEP 2 - Data Preparation

# Generate synthetic data for the example
np.random.seed(0)
hours_studied = np.random.uniform(0, 10, 100) # Random hours studied (0 to 10 hours)
exam_scores  = 50 + 5 * hours_studied + np.random.normal(0,2,100)

data = pd.DataFrame({'Hours_Studied':hours_studied,'Exam_Scores':exam_scores})

# %%
#STEP 3 - Data Splitting

x=data[['Hours_Studied']]
y=data['Exam_Scores']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
#STEP 4 - Data

#Create and train model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#STEP 5 - Model Evaluation

#Make predictions on the testing data
y_pred = model.predict (x_test)

#Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'R Squared: {r2:.2f}')
# Out:
# Mean Squared Error: 3.67
# R Squared: 0.97

# %%
#STEP 6 - Visualization and Interpretation

#Plot the reg line and data points

plt.scatter(x_test, y_test, color='blue', label='Actual Data')
plt.plot(x_test, y_pred, color='red', label='Regression Line', linewidth=2)
plt.xlabel('Hours Studied')
plt.ylabel('Exam Scores')
plt.legend()
plt.title('Simple Linear Regression: Hours Studied vs Exam Scores')
plt.show()
